# %%
import qcportal as ptl
import tqdm
import pathlib
import numpy as np
import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq
import pyarrow.dataset as ds
from offqcdata.download import download_optimization, get_client, download_torsiondrive

# %%
client = get_client("_cache")

# %%
IGNORE_IODINE = [
    "OpenFF Discrepancy Benchmark 1",
    "OpenFF Gen 2 Opt Set 2 Coverage",
    "OpenFF Gen 2 Opt Set 4 eMolecules Discrepancy",
    "SMIRNOFF Coverage Set 1",
    "OpenFF Ehrman Informative Optimization v0.2",
    "FDA optimization dataset 1",
    "Kinase Inhibitors: WBO Distributions",

    # ---
    "OpenFF Gen 2 Torsion Set 2 Coverage 2",
    "OpenFF Gen 2 Torsion Set 4 eMolecules Discrepancy 2",
]

# %%
OPTIMIZATION_WHITELISTS = [
    "OpenFF Optimization Set 1",
    "SMIRNOFF Coverage Set 1",
    "OpenFF VEHICLe Set 1",
    "OpenFF Discrepancy Benchmark 1",
    "OpenFF Ehrman Informative Optimization v0.2",
    "Pfizer discrepancy optimization dataset 1",
    "FDA optimization dataset 1",
    "Kinase Inhibitors: WBO Distributions",
    "OpenFF Gen 2 Opt Set 1 Roche",
    "OpenFF Gen 2 Opt Set 2 Coverage",
    "OpenFF Gen 2 Opt Set 3 Pfizer Discrepancy",
    "OpenFF Gen 2 Opt Set 4 eMolecules Discrepancy",
    "OpenFF Gen 2 Opt Set 5 Bayer",
    "OpenFF Sandbox CHO PhAlkEthOH v1.0",
    "OpenFF Industry Benchmark Season 1 v1.1",
    "OpenFF Gen2 Optimization Dataset Protomers v1.0",
    "OpenFF Protein Capped 1-mers 3-mers Optimization Dataset v1.0",
    "OpenFF Iodine Chemistry Optimization Dataset v1.0",
    # "OpenFF multi-Br ESP Fragment Conformers v1.0",
    "XtalPi Shared Fragments OptimizationDataset v1.0",
    "XtalPi 20-percent Fragments OptimizationDataset v1.0",
    "OpenFF Torsion Benchmark Supplement v1.0",
    "OpenFF Torsion Multiplicity Optimization Training Coverage Supplement v1.0",
    "OpenFF Torsion Multiplicity Optimization Benchmarking Coverage Supplement v1.0",
    "OpenFF Iodine Fragment Opt v1.0",
    "OpenFF Sulfur Optimization Training Coverage Supplement v1.0",
    "OpenFF Sulfur Optimization Benchmarking Coverage Supplement v1.0",
    "OpenFF Lipid Optimization Training Supplement v1.0",
    "OpenFF Lipid Optimization Benchmark Supplement v1.0",
    # "SPICE DES370k Monomers Lowest E Conformer Optimization Dataset v4.0",
    "OpenFF Cresset Additional Coverage Optimizations v4.0",
    "OpenFF Protein PDB 4-mers v4.0"
]

# %%
TORSIONDRIVE_WHITELISTS = [
    "OpenFF Group1 Torsions",
    "SMIRNOFF Coverage Torsion Set 1",
    "OpenFF Substituted Phenyl Set 1",
    "Pfizer discrepancy torsion dataset 1",
    "OpenFF Primary Benchmark 1 Torsion Set",
    "OpenFF Gen 2 Torsion Set 2 Coverage 2",
    "OpenFF Gen 2 Torsion Set 3 Pfizer Discrepancy 2",
    "OpenFF Gen 2 Torsion Set 4 eMolecules Discrepancy 2",
    "OpenFF Gen 2 Torsion Set 5 Bayer 2",
    "OpenFF Gen 2 Torsion Set 6 supplemental 2",
    "OpenFF Fragmenter Validation 1.0",
    "OpenFF DANCE 1 eMolecules t142 v1.0",
    "OpenFF Rowley Biaryl v1.0",
    "OpenFF-benchmark-ligand-fragments-v1.0",
    "OpenFF Protein Fragments TorsionDrives v1.0",
    "OpenFF WBO Conjugated Series v1.0",
    "OpenFF Amide Torsion Set v1.0",
    # "OpenFF Aniline Para Opt v1.0",
    "OpenFF Gen3 Torsion Set v1.0",
    "OpenFF Aniline 2D Impropers v1.0",
    "OpenFF-benchmark-ligand-fragments-v2.0",
    "OpenFF multiplicity correction torsion drive data v1.1",
    "OpenFF Protein Capped 3-mer Omega v1.0",
    "XtalPi Shared Fragments TorsiondriveDataset v1.0",
    "OpenFF Torsion Coverage Supplement v1.0",
    "OpenFF RNA Dinucleoside Monophosphate TorsionDrives v1.0",
    "XtalPi 20-percent Fragments TorsiondriveDataset v1.0",
    "OpenFF Torsion Drive Supplement v1.0",
    "OpenFF Torsion Multiplicity Torsion Drive Coverage Supplement v1.0",
    "OpenFF Phosphate Torsion Drives v1.0",
    "OpenFF Alkane Torsion Drives v1.0",
    "OpenFF Cresset Additional Coverage TorsionDrives v4.0"
]

# %%
for dsname in tqdm.tqdm(["SPICE DES370k Monomers Lowest E Conformer Optimization Dataset v4.0"]):
    table = download_optimization(client, dsname)
    print(table)
    if dsname in IGNORE_IODINE:
        df = table.to_pandas()
        n_df = len(df)
        mask = np.array(["I" in smi for smi in df.smiles.values])
        print(df[mask].smiles)
        df = pd.DataFrame(df[~mask])
        print(f"Found {len(mask)} in {dsname} -- filtering from {n_df} to {len(df)}")
        table = pa.Table.from_pandas(df)

    pq.write_table(table, f"offqcdata/data/tables/optimization/{dsname}.parquet")
# Out:
# 100%|█████████████████████████████████████████████| 1/1 [00:02<00:00,  2.23s/it]
# pyarrow.Table
#
# ----

# %%
for dsname in tqdm.tqdm(OPTIMIZATION_WHITELISTS):
    table = download_optimization(client, dsname)
    if dsname in IGNORE_IODINE:
        df = table.to_pandas()
        n_df = len(df)
        mask = np.array(["I" in smi for smi in df.smiles.values])
        print(df[mask].smiles)
        df = pd.DataFrame(df[~mask])
        print(f"Found {len(mask)} in {dsname} -- filtering from {n_df} to {len(df)}")
        table = pa.Table.from_pandas(df)

    pq.write_table(table, f"offqcdata/data/tables/optimization/{dsname}.parquet")
# Out:
#   6%|████████▎                                                                                                                            | 2/32 [00:09<02:29,  4.97s/it]
# 310        Ic1ccc(OC2CC2)cc1
# 311        Ic1ccc(OC2CC2)cc1
# 314       [O-]c1ccc([O-])n1I
# 315       [O-]c1ccc([O-])n1I
# 320          [O-]c1ccc(O)n1I
# 321          [O-]c1ccc(O)n1I
# 322             Oc1ccc(O)n1I
# 430           O=C1CCC(=O)N1I
# 431             Oc1ccc(O)n1I
# 494    Cc1ccc(S(=O)(=O)I)cc1
# 495    Cc1ccc(S(=O)(=O)I)cc1
# 512                     ClCI
# 742     COc1cc(F)c([O-])cc1I
# 743     COc1cc(F)c([O-])cc1I
# 744        COc1cc(F)c(O)cc1I
# 745        COc1cc(F)c(O)cc1I
# Name: smiles, dtype: object
# Found 1132 in SMIRNOFF Coverage Set 1 -- filtering from 1132 to 1116
#  12%|████████████████▋                                                                                                                    | 4/32 [03:07<28:20, 60.72s/it]
# 1375     O=C(O)c1cc(/C=N/c2ccccc2I)nc2ccccc12
# 1376     O=C(O)c1cc(/C=N/c2ccccc2I)nc2ccccc12
# 1377     O=C(O)c1cc(/C=N/c2ccccc2I)nc2ccccc12
# 1378     O=C(O)c1cc(/C=N/c2ccccc2I)nc2ccccc12
# 1379     O=C(O)c1cc(/C=N/c2ccccc2I)nc2ccccc12
#                          ...
# 19317                     COc1ccnc2ccc(I)cc12
# 19424                COC(=O)c1cc(C#N)cc(I)c1O
# 19425                COC(=O)c1cc(C#N)cc(I)c1O
# 19527                      COC(=O)c1nc(N)sc1I
# 19528                      COC(=O)c1nc(N)sc1I
# Name: smiles, Length: 264, dtype: object
# Found 19714 in OpenFF Discrepancy Benchmark 1 -- filtering from 19714 to 19450
#  16%|████████████████████▊                                                                                                                | 5/32 [03:23<20:02, 44.53s/it]
# 684     O=C(Nc1ccc(Cl)cc1Cl)c1cc(I)cc(I)c1O
# 685     O=C(Nc1ccc(Cl)cc1Cl)c1cc(I)cc(I)c1O
# 686     O=C(Nc1ccc(Cl)cc1Cl)c1cc(I)cc(I)c1O
# 687     O=C(Nc1ccc(Cl)cc1Cl)c1cc(I)cc(I)c1O
# 688     O=C(Nc1ccc(Cl)cc1Cl)c1cc(I)cc(I)c1O
#                        ...
# 3340                       COc1ccc(C=O)cc1I
# 3341                        COc1ccc(Cl)cc1I
# 3350              COc1cccc(I)c1[N+](=O)[O-]
# 3354                         COc1cccc(F)c1I
# 3362                            COc1ccccc1I
# Name: smiles, Length: 74, dtype: object
# Found 3485 in OpenFF Ehrman Informative Optimization v0.2 -- filtering from 3485 to 3411
#  22%|█████████████████████████████                                                                                                        | 7/32 [03:54<12:20, 29.61s/it]
# 41                              [O-]c1c(I)cc(Cl)c2cccnc12
# 42                                 Oc1c(I)cc(Cl)c2cccnc12
# 790     [NH3+][C@@H](Cc1cc(I)c(Oc2cc(I)c([O-])c(I)c2)c...
# 791     [NH3+][C@@H](Cc1cc(I)c(Oc2cc(I)c([O-])c(I)c2)c...
# 792     [NH3+][C@@H](Cc1cc(I)c(Oc2cc(I)c([O-])c(I)c2)c...
#                               ...
# 6545    COC(=O)[C@H]1[C@@H](c2ccc(I)cc2)C[C@@H]2CC[C@H...
# 6546    COC(=O)[C@H]1[C@@H](c2ccc(I)cc2)C[C@@H]2CC[C@H...
# 6547    COC(=O)[C@H]1[C@@H](c2ccc(I)cc2)C[C@@H]2CC[C@H...
# 6548    COC(=O)[C@H]1[C@@H](c2ccc(I)cc2)C[C@@H]2CC[C@H...
# 6549    COC(=O)[C@H]1[C@@H](c2ccc(I)cc2)C[C@@H]2CC[C@H...
# Name: smiles, Length: 96, dtype: object
# Found 6670 in FDA optimization dataset 1 -- filtering from 6670 to 6574
#  25%|█████████████████████████████████▎                                                                                                   | 8/32 [04:20<11:26, 28.62s/it]
# Series([], Name: smiles, dtype: object)
# Found 958 in Kinase Inhibitors: WBO Distributions -- filtering from 958 to 958
#  31%|█████████████████████████████████████████▎                                                                                          | 10/32 [04:25<05:27, 14.87s/it]
# 133                     ClCI
# 150             Oc1ccc(O)n1I
# 207    Cc1ccc(S(=O)(=O)I)cc1
# 245     COc1cc(F)c([O-])cc1I
# Name: smiles, dtype: object
# Found 373 in OpenFF Gen 2 Opt Set 2 Coverage -- filtering from 373 to 369
#  38%|█████████████████████████████████████████████████▌                                                                                  | 12/32 [04:37<03:34, 10.73s/it]
# 274                   O=[N+]([O-])c1ccc(Br)cc1I
# 625                O=[N+]([O-])c1cc(I)c(F)cc1Br
# 639                          O=C(O)c1cccc(I)c1O
# 640                          O=C(O)c1cccc(I)c1O
# 641                          O=C(O)c1cccc(I)c1O
# 683                      Ic1cccc([C@@H]2CCN2)c1
# 684                      Ic1cccc([C@@H]2CCN2)c1
# 712        N#C/C(=N/Nc1ccc(I)cc1)c1nnc2n1CCCCC2
# 713        N#C/C(=N/Nc1ccc(I)cc1)c1nnc2n1CCCCC2
# 714        N#C/C(=N/Nc1ccc(I)cc1)c1nnc2n1CCCCC2
# 715        N#C/C(=N/Nc1ccc(I)cc1)c1nnc2n1CCCCC2
# 716        N#C/C(=N/Nc1ccc(I)cc1)c1nnc2n1CCCCC2
# 717        N#C/C(=N/Nc1ccc(I)cc1)c1nnc2n1CCCCC2
# 718        N#C/C(=N/Nc1ccc(I)cc1)c1nnc2n1CCCCC2
# 719        N#C/C(=N/Nc1ccc(I)cc1)c1nnc2n1CCCCC2
# 720        N#C/C(=N/Nc1ccc(I)cc1)c1nnc2n1CCCCC2
# 721        N#C/C(=N/Nc1ccc(I)cc1)c1nnc2n1CCCCC2
# 722        N#C/C(=N/Nc1ccc(I)cc1)c1nnc2n1CCCCC2
# 723        N#C/C(=N/Nc1ccc(I)cc1)c1nnc2n1CCCCC2
# 724        N#C/C(=N/Nc1ccc(I)cc1)c1nnc2n1CCCCC2
# 725        N#C/C(=N/Nc1ccc(I)cc1)c1nnc2n1CCCCC2
# 726        N#C/C(=N/Nc1ccc(I)cc1)c1nnc2n1CCCCC2
# 809                        FC(F)(F)Sc1cccc(I)n1
# 810                        FC(F)(F)Sc1cccc(I)n1
# 811                        FC(F)(F)Sc1cccc(I)n1
# 1004           Cc1c([N+](=O)[O-])cc(Cl)c(I)c1Cl
# 1351    Cc1cc(C)nc(N/N=C/c2c(C)nc3ccc(I)cn23)n1
# 1352    Cc1cc(C)nc(N/N=C/c2c(C)nc3ccc(I)cn23)n1
# 1353    Cc1cc(C)nc(N/N=C/c2c(C)nc3ccc(I)cn23)n1
# 1354    Cc1cc(C)nc(N/N=C/c2c(C)nc3ccc(I)cn23)n1
# 1355    Cc1cc(C)nc(N/N=C/c2c(C)nc3ccc(I)cn23)n1
# 1438                       CC(=O)Cn1cc(I)c(C)n1
# 1439                       CC(=O)Cn1cc(I)c(C)n1
# 1440                       CC(=O)Cn1cc(I)c(C)n1
# 1441                       CC(=O)Cn1cc(I)c(C)n1
# 1442                       CC(=O)Cn1cc(I)c(C)n1
# 1443                         CC(=O)Cn1ncc(I)c1C
# 1444                         CC(=O)Cn1ncc(I)c1C
# 1445                         CC(=O)Cn1ncc(I)c1C
# 1446                         CC(=O)Cn1ncc(I)c1C
# 1815              CC(C)(C#N)C(=O)Nc1cc(I)ccc1Cl
# 1816              CC(C)(C#N)C(=O)Nc1cc(I)ccc1Cl
# 1817              CC(C)(C#N)C(=O)Nc1cc(I)ccc1Cl
# Name: smiles, dtype: object
# Found 2201 in OpenFF Gen 2 Opt Set 4 eMolecules Discrepancy -- filtering from 2201 to 2158
#  62%|█████████████████████████████████████████████████████████████████████████████████▉                                                 | 20/32 [45:31<24:35, 122.97s/it][08:59:13] Explicit valence for atom # 10 N, 5, is greater than permitted
# [08:59:13] Explicit valence for atom # 10 N, 5, is greater than permitted
# [08:59:13] Explicit valence for atom # 10 N, 5, is greater than permitted
# [08:59:13] Explicit valence for atom # 10 N, 5, is greater than permitted
# Invalid SMILES: [C:1]1([H:13])=[C:2]([H:14])[C:10](=[C:9]2[C:3]([H:15])=[C:6]([H:18])[N:11]([H:21])[C:7]([H:19])=[C:4]2[H:16])[C:8]([H:20])=[N+2:12]([H:22])=[C:5]1[H:17]
# Invalid SMILES: [C:1]1([H:13])=[C:2]([H:14])[C:10](=[C:9]2[C:3]([H:15])=[C:6]([H:18])[N:11]([H:21])[C:7]([H:19])=[C:4]2[H:16])[C:8]([H:20])=[N+2:12]([H:22])=[C:5]1[H:17]
# Invalid SMILES: [C:1]1([H:13])=[C:2]([H:14])[C:10](=[C:9]2[C:3]([H:15])=[C:6]([H:18])[N:11]([H:21])[C:7]([H:19])=[C:4]2[H:16])[C:8]([H:20])=[N+2:12]([H:22])=[C:5]1[H:17]
# Invalid SMILES: [C:1]1([H:13])=[C:2]([H:14])[C:10](=[C:9]2[C:3]([H:15])=[C:6]([H:18])[N:11]([H:21])[C:7]([H:19])=[C:4]2[H:16])[C:8]([H:20])=[N+2:12]([H:22])=[C:5]1[H:17]
# [09:02:52] Explicit valence for atom # 10 N, 5, is greater than permitted
# [09:02:52] Explicit valence for atom # 10 N, 5, is greater than permitted
# [09:02:52] Explicit valence for atom # 10 N, 5, is greater than permitted
# [09:02:52] Explicit valence for atom # 10 N, 5, is greater than permitted
# [09:02:52] Explicit valence for atom # 10 N, 5, is greater than permitted
# [09:02:52] Explicit valence for atom # 10 N, 5, is greater than permitted
# [09:02:52] Explicit valence for atom # 10 N, 5, is greater than permitted
# [09:02:52] Explicit valence for atom # 10 N, 5, is greater than permitted
# [09:02:52] Explicit valence for atom # 10 N, 5, is greater than permitted
# [09:02:52] Explicit valence for atom # 10 N, 5, is greater than permitted
# [09:02:52] Explicit valence for atom # 10 N, 5, is greater than permitted
# [09:02:52] Explicit valence for atom # 10 N, 5, is greater than permitted
# [09:02:52] Explicit valence for atom # 10 N, 5, is greater than permitted
# [09:02:52] Explicit valence for atom # 10 N, 5, is greater than permitted
# [09:02:52] Explicit valence for atom # 10 N, 5, is greater than permitted
# [09:02:52] Explicit valence for atom # 10 N, 5, is greater than permitted
# [09:02:52] Explicit valence for atom # 10 N, 5, is greater than permitted
# [09:02:52] Explicit valence for atom # 10 N, 5, is greater than permitted
# [09:02:52] Explicit valence for atom # 10 N, 5, is greater than permitted
# [09:02:52] Explicit valence for atom # 10 N, 5, is greater than permitted
# [09:02:52] Explicit valence for atom # 10 N, 5, is greater than permitted
# [09:02:52] Explicit valence for atom # 10 N, 5, is greater than permitted
# [09:02:52] Explicit valence for atom # 10 N, 5, is greater than permitted
# [09:02:52] Explicit valence for atom # 10 N, 5, is greater than permitted
# [09:02:52] Explicit valence for atom # 10 N, 5, is greater than permitted
# [09:02:52] Explicit valence for atom # 10 N, 5, is greater than permitted
# [09:02:52] Explicit valence for atom # 10 N, 5, is greater than permitted
# [09:02:52] Explicit valence for atom # 10 N, 5, is greater than permitted
# [09:02:52] Explicit valence for atom # 10 N, 5, is greater than permitted
# [09:02:52] Explicit valence for atom # 10 N, 5, is greater than permitted
# Invalid SMILES: [c:1]1([H:16])[c:2]([H:17])[c:4]([H:19])[c:9]([C:6]([N:11]=[C:8]([N:12]=[C:10]2[C:7]([H:23])=[N+2:13]([H:25])=[N:14][O:15]2)[H:24])([H:21])[H:22])[c:5]([H:20])[c:3]1[H:18]
# Invalid SMILES: [c:1]1([H:16])[c:2]([H:17])[c:4]([H:19])[c:9]([C:6]([N:11]=[C:8]([N:12]=[C:10]2[C:7]([H:23])=[N+2:13]([H:25])=[N:14][O:15]2)[H:24])([H:21])[H:22])[c:5]([H:20])[c:3]1[H:18]
# Invalid SMILES: [c:1]1([H:16])[c:2]([H:17])[c:4]([H:19])[c:9]([C:6]([N:11]=[C:8]([N:12]=[C:10]2[C:7]([H:23])=[N+2:13]([H:25])=[N:14][O:15]2)[H:24])([H:21])[H:22])[c:5]([H:20])[c:3]1[H:18]
# Invalid SMILES: [c:1]1([H:16])[c:2]([H:17])[c:4]([H:19])[c:9]([C:6]([N:11]=[C:8]([N:12]=[C:10]2[C:7]([H:23])=[N+2:13]([H:25])=[N:14][O:15]2)[H:24])([H:21])[H:22])[c:5]([H:20])[c:3]1[H:18]
# Invalid SMILES: [c:1]1([H:16])[c:2]([H:17])[c:4]([H:19])[c:9]([C:6]([N:11]=[C:8]([N:12]=[C:10]2[C:7]([H:23])=[N+2:13]([H:25])=[N:14][O:15]2)[H:24])([H:21])[H:22])[c:5]([H:20])[c:3]1[H:18]
# Invalid SMILES: [c:1]1([H:16])[c:2]([H:17])[c:4]([H:19])[c:9]([C:6]([N:11]=[C:8]([N:12]=[C:10]2[C:7]([H:23])=[N+2:13]([H:25])=[N:14][O:15]2)[H:24])([H:21])[H:22])[c:5]([H:20])[c:3]1[H:18]
# Invalid SMILES: [c:1]1([H:16])[c:2]([H:17])[c:4]([H:19])[c:9]([C:6]([N:11]=[C:8]([N:12]=[C:10]2[C:7]([H:23])=[N+2:13]([H:25])=[N:14][O:15]2)[H:24])([H:21])[H:22])[c:5]([H:20])[c:3]1[H:18]
# Invalid SMILES: [c:1]1([H:16])[c:2]([H:17])[c:4]([H:19])[c:9]([C:6]([N:11]=[C:8]([N:12]=[C:10]2[C:7]([H:23])=[N+2:13]([H:25])=[N:14][O:15]2)[H:24])([H:21])[H:22])[c:5]([H:20])[c:3]1[H:18]
# Invalid SMILES: [c:1]1([H:16])[c:2]([H:17])[c:4]([H:19])[c:9]([C:6]([N:11]=[C:8]([N:12]=[C:10]2[C:7]([H:23])=[N+2:13]([H:25])=[N:14][O:15]2)[H:24])([H:21])[H:22])[c:5]([H:20])[c:3]1[H:18]
# Invalid SMILES: [c:1]1([H:16])[c:2]([H:17])[c:4]([H:19])[c:9]([C:6]([N:11]=[C:8]([N:12]=[C:10]2[C:7]([H:23])=[N+2:13]([H:25])=[N:14][O:15]2)[H:24])([H:21])[H:22])[c:5]([H:20])[c:3]1[H:18]
# Invalid SMILES: [c:1]1([H:16])[c:2]([H:17])[c:4]([H:19])[c:9]([C:6]([N:11]=[C:8]([N:12]=[C:10]2[C:7]([H:23])=[N+2:13]([H:25])=[N:14][O:15]2)[H:24])([H:21])[H:22])[c:5]([H:20])[c:3]1[H:18]
# Invalid SMILES: [c:1]1([H:16])[c:2]([H:17])[c:4]([H:19])[c:9]([C:6]([N:11]=[C:8]([N:12]=[C:10]2[C:7]([H:23])=[N+2:13]([H:25])=[N:14][O:15]2)[H:24])([H:21])[H:22])[c:5]([H:20])[c:3]1[H:18]
# Invalid SMILES: [c:1]1([H:16])[c:2]([H:17])[c:4]([H:19])[c:9]([C:6]([N:11]=[C:8]([N:12]=[C:10]2[C:7]([H:23])=[N+2:13]([H:25])=[N:14][O:15]2)[H:24])([H:21])[H:22])[c:5]([H:20])[c:3]1[H:18]
# Invalid SMILES: [c:1]1([H:16])[c:2]([H:17])[c:4]([H:19])[c:9]([C:6]([N:11]=[C:8]([N:12]=[C:10]2[C:7]([H:23])=[N+2:13]([H:25])=[N:14][O:15]2)[H:24])([H:21])[H:22])[c:5]([H:20])[c:3]1[H:18]
# Invalid SMILES: [c:1]1([H:16])[c:2]([H:17])[c:4]([H:19])[c:9]([C:6]([N:11]=[C:8]([N:12]=[C:10]2[C:7]([H:23])=[N+2:13]([H:25])=[N:14][O:15]2)[H:24])([H:21])[H:22])[c:5]([H:20])[c:3]1[H:18]
# Invalid SMILES: [c:1]1([H:16])[c:2]([H:17])[c:4]([H:19])[c:9]([C:6]([N:11]=[C:8]([N:12]=[C:10]2[C:7]([H:23])=[N+2:13]([H:25])=[N:14][O:15]2)[H:24])([H:21])[H:22])[c:5]([H:20])[c:3]1[H:18]
# Invalid SMILES: [c:1]1([H:16])[c:2]([H:17])[c:4]([H:19])[c:9]([C:6]([N:11]=[C:8]([N:12]=[C:10]2[C:7]([H:23])=[N+2:13]([H:25])=[N:14][O:15]2)[H:24])([H:21])[H:22])[c:5]([H:20])[c:3]1[H:18]
# Invalid SMILES: [c:1]1([H:16])[c:2]([H:17])[c:4]([H:19])[c:9]([C:6]([N:11]=[C:8]([N:12]=[C:10]2[C:7]([H:23])=[N+2:13]([H:25])=[N:14][O:15]2)[H:24])([H:21])[H:22])[c:5]([H:20])[c:3]1[H:18]
# Invalid SMILES: [c:1]1([H:16])[c:2]([H:17])[c:4]([H:19])[c:9]([C:6]([N:11]=[C:8]([N:12]=[C:10]2[C:7]([H:23])=[N+2:13]([H:25])=[N:14][O:15]2)[H:24])([H:21])[H:22])[c:5]([H:20])[c:3]1[H:18]
# Invalid SMILES: [c:1]1([H:16])[c:2]([H:17])[c:4]([H:19])[c:9]([C:6]([N:11]=[C:8]([N:12]=[C:10]2[C:7]([H:23])=[N+2:13]([H:25])=[N:14][O:15]2)[H:24])([H:21])[H:22])[c:5]([H:20])[c:3]1[H:18]
# Invalid SMILES: [c:1]1([H:16])[c:2]([H:17])[c:4]([H:19])[c:9]([C:6]([N:11]=[C:8]([N:12]=[C:10]2[C:7]([H:23])=[N+2:13]([H:25])=[N:14][O:15]2)[H:24])([H:21])[H:22])[c:5]([H:20])[c:3]1[H:18]
# Invalid SMILES: [c:1]1([H:16])[c:2]([H:17])[c:4]([H:19])[c:9]([C:6]([N:11]=[C:8]([N:12]=[C:10]2[C:7]([H:23])=[N+2:13]([H:25])=[N:14][O:15]2)[H:24])([H:21])[H:22])[c:5]([H:20])[c:3]1[H:18]
# Invalid SMILES: [c:1]1([H:16])[c:2]([H:17])[c:4]([H:19])[c:9]([C:6]([N:11]=[C:8]([N:12]=[C:10]2[C:7]([H:23])=[N+2:13]([H:25])=[N:14][O:15]2)[H:24])([H:21])[H:22])[c:5]([H:20])[c:3]1[H:18]
# Invalid SMILES: [c:1]1([H:16])[c:2]([H:17])[c:4]([H:19])[c:9]([C:6]([N:11]=[C:8]([N:12]=[C:10]2[C:7]([H:23])=[N+2:13]([H:25])=[N:14][O:15]2)[H:24])([H:21])[H:22])[c:5]([H:20])[c:3]1[H:18]
# Invalid SMILES: [c:1]1([H:16])[c:2]([H:17])[c:4]([H:19])[c:9]([C:6]([N:11]=[C:8]([N:12]=[C:10]2[C:7]([H:23])=[N+2:13]([H:25])=[N:14][O:15]2)[H:24])([H:21])[H:22])[c:5]([H:20])[c:3]1[H:18]
# Invalid SMILES: [c:1]1([H:16])[c:2]([H:17])[c:4]([H:19])[c:9]([C:6]([N:11]=[C:8]([N:12]=[C:10]2[C:7]([H:23])=[N+2:13]([H:25])=[N:14][O:15]2)[H:24])([H:21])[H:22])[c:5]([H:20])[c:3]1[H:18]
# Invalid SMILES: [c:1]1([H:16])[c:2]([H:17])[c:4]([H:19])[c:9]([C:6]([N:11]=[C:8]([N:12]=[C:10]2[C:7]([H:23])=[N+2:13]([H:25])=[N:14][O:15]2)[H:24])([H:21])[H:22])[c:5]([H:20])[c:3]1[H:18]
# Invalid SMILES: [c:1]1([H:16])[c:2]([H:17])[c:4]([H:19])[c:9]([C:6]([N:11]=[C:8]([N:12]=[C:10]2[C:7]([H:23])=[N+2:13]([H:25])=[N:14][O:15]2)[H:24])([H:21])[H:22])[c:5]([H:20])[c:3]1[H:18]
# Invalid SMILES: [c:1]1([H:16])[c:2]([H:17])[c:4]([H:19])[c:9]([C:6]([N:11]=[C:8]([N:12]=[C:10]2[C:7]([H:23])=[N+2:13]([H:25])=[N:14][O:15]2)[H:24])([H:21])[H:22])[c:5]([H:20])[c:3]1[H:18]
# Invalid SMILES: [c:1]1([H:16])[c:2]([H:17])[c:4]([H:19])[c:9]([C:6]([N:11]=[C:8]([N:12]=[C:10]2[C:7]([H:23])=[N+2:13]([H:25])=[N:14][O:15]2)[H:24])([H:21])[H:22])[c:5]([H:20])[c:3]1[H:18]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 32/32 [1:03:19<00:00, 118.73s/it]

# %%
for dsname in tqdm.tqdm(OPTIMIZATION_WHITELISTS[16:]):
    table = download_optimization(client, dsname)
    if dsname in IGNORE_IODINE:
        df = table.to_pandas()
        n_df = len(df)
        mask = np.array(["I" in smi for smi in df.smiles.values])
        print(df[mask].smiles)
        df = pd.DataFrame(df[~mask])
        print(f"Found {len(mask)} in {dsname} -- filtering from {n_df} to {len(df)}")
        table = pa.Table.from_pandas(df)

    pq.write_table(table, f"offqcdata/data/tables/optimization/{dsname}.parquet")
# Out:
#  25%|█████████████████████████████████▎                                                                                                   | 4/16 [00:19<01:04,  5.36s/it][21:29:53] Explicit valence for atom # 10 N, 5, is greater than permitted
#  25%|█████████████████████████████████▎                                                                                                   | 4/16 [01:41<05:04, 25.35s/it]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 2
#       1 for dsname in tqdm.tqdm(OPTIMIZATION_WHITELISTS[16:]):
# ----> 2     table = download_optimization(client, dsname)
#       3     if dsname in IGNORE_IODINE:
#       4         df = table.to_pandas()
#
# File ~/pydev/profile-qc-data/offqcdata/download.py:39, in download_optimization(client, dataset_name)
#      37 entry = entries[name]
#      38 cmiles = get_canonical_smiles(entry)
# ---> 39 smiles = sanitize_smiles(cmiles)
#      40 data_entry = {
#      41     "id": record.id,
#      42     "cmiles": cmiles,
#      43     "smiles": smiles,
#      44     "dataset_name": dataset_name
#      45 }
#      46 data_entries.append(data_entry)
#
# File ~/pydev/profile-qc-data/offqcdata/download.py:10, in sanitize_smiles(smiles)
#       8 def sanitize_smiles(smiles: str) -> str:
#       9     mol = Chem.MolFromSmiles(smiles)
# ---> 10     for atom in mol.GetAtoms():
#      11         atom.SetAtomMapNum(0)
#      12     return Chem.MolToSmiles(mol)
#
# AttributeError: 'NoneType' object has no attribute 'GetAtoms'

# %%
for dsname in tqdm.tqdm(OPTIMIZATION_WHITELISTS[21:]):
    table = download_optimization(client, dsname)
    if dsname in IGNORE_IODINE:
        df = table.to_pandas()
        n_df = len(df)
        mask = np.array(["I" in smi for smi in df.smiles.values])
        print(df[mask].smiles)
        df = pd.DataFrame(df[~mask])
        print(f"Found {len(mask)} in {dsname} -- filtering from {n_df} to {len(df)}")
        table = pa.Table.from_pandas(df)

    pq.write_table(table, f"offqcdata/data/tables/optimization/{dsname}.parquet")
# Out:
#   0%|                                                                                                                                             | 0/11 [00:02<?, ?it/s]
# ---------------------------------------------------------------------------
# PortalRequestError                        Traceback (most recent call last)
# Cell In[11], line 2
#       1 for dsname in tqdm.tqdm(OPTIMIZATION_WHITELISTS[21:]):
# ----> 2     table = download_optimization(client, dsname)
#       3     if dsname in IGNORE_IODINE:
#       4         df = table.to_pandas()
#
# File ~/pydev/profile-qc-data/offqcdata/download.py:28, in download_optimization(client, dataset_name)
#      27 def download_optimization(client, dataset_name: str):
# ---> 28     dataset = client.get_dataset("optimization", dataset_name)
#      29     entries = {
#      30         entry.name: entry
#      31         for entry in dataset.iterate_entries()
#      32     }
#      33     data_entries = []
#
# File ~/micromamba/envs/offqcdata-test/lib/python3.12/site-packages/qcportal/client.py:236, in PortalClient.get_dataset(self, dataset_type, dataset_name)
#     234 def get_dataset(self, dataset_type: str, dataset_name: str):
#     235     body = DatasetQueryModel(dataset_name=dataset_name, dataset_type=dataset_type)
# --> 236     ds = self.make_request("post", f"api/v1/datasets/query", Dict[str, Any], body=body)
#     238     return dataset_from_dict(ds, self)
#
# File ~/micromamba/envs/offqcdata-test/lib/python3.12/site-packages/qcportal/client_base.py:495, in PortalClientBase.make_request(self, method, endpoint, response_model, body_model, url_params_model, body, url_params, allow_retries, additional_headers)
#     492 if isinstance(parsed_url_params, pydantic.BaseModel):
#     493     parsed_url_params = parsed_url_params.dict()
# --> 495 r = self._request(
#     496     method,
#     497     endpoint,
#     498     body=serialized_body,
#     499     url_params=parsed_url_params,
#     500     allow_retries=allow_retries,
#     501     additional_headers=additional_headers,
#     502 )
#     503 d = deserialize(r.content, r.headers["Content-Type"])
#     505 if response_model is None:
#
# File ~/micromamba/envs/offqcdata-test/lib/python3.12/site-packages/qcportal/client_base.py:459, in PortalClientBase._request(self, method, endpoint, body, url_params, internal_retry, allow_retries, additional_headers)
#     454     except:
#     455         # If this error comes from, ie, the web server or something else, then
#     456         # we have to use 'reason'
#     457         details = {"msg": r.reason}
# --> 459     raise PortalRequestError(f"Request failed: {details['msg']}", r.status_code, details)
#     461 return r
#
# PortalRequestError: Request failed: Could not find optimization dataset with name 'OpenFF Torsion Benchmark Supplement Optimization Dataset v1.0' (HTTP status 400)

# %%
for dsname in tqdm.tqdm(TORSIONDRIVE_WHITELISTS[23:]):
    print(dsname)
    table = download_torsiondrive(client, dsname)
    if dsname in IGNORE_IODINE:
        df = table.to_pandas()
        n_df = len(df)
        mask = np.array(["I" in smi for smi in df.smiles.values])
        print(df[mask].smiles)
        df = pd.DataFrame(df[~mask])
        print(f"Found {len(mask)} in {dsname} -- filtering from {n_df} to {len(df)}")
        table = pa.Table.from_pandas(df)

    pq.write_table(table, f"offqcdata/data/tables/torsiondrive/{dsname}.parquet")
# Out:
#   0%|                                                     | 0/8 [00:00<?, ?it/s]
# OpenFF Torsion Coverage Supplement v1.0
#  12%|█████▋                                       | 1/8 [00:02<00:15,  2.26s/it]
# OpenFF RNA Dinucleoside Monophosphate TorsionDrives v1.0
#  25%|███████████▎                                 | 2/8 [00:24<01:25, 14.25s/it]
# XtalPi 20-percent Fragments TorsiondriveDataset v1.0
# [14:58:44] Explicit valence for atom # 10 N, 5, is greater than permitted
# Invalid SMILES: [C:1]1([H:13])=[C:2]([H:14])[C:10](=[C:9]2[C:3]([H:15])=[C:6]([H:18])[N:11]([H:21])[C:7]([H:19])=[C:4]2[H:16])[C:8]([H:20])=[N+2:12]([H:22])=[C:5]1[H:17]
# [14:58:52] Explicit valence for atom # 10 N, 5, is greater than permitted
# Invalid SMILES: [c:1]1([H:16])[c:2]([H:17])[c:4]([H:19])[c:9]([C:6]([N:11]=[C:8]([N:12]=[C:10]2[C:7]([H:23])=[N+2:13]([H:25])=[N:14][O:15]2)[H:24])([H:21])[H:22])[c:5]([H:20])[c:3]1[H:18]
#  38%|████████████████▉                            | 3/8 [02:26<05:15, 63.16s/it]
# OpenFF Torsion Drive Supplement v1.0
#  50%|██████████████████████▌                      | 4/8 [02:28<02:36, 39.01s/it]
# OpenFF Torsion Multiplicity Torsion Drive Coverage Supplement v1.0
#  62%|████████████████████████████▏                | 5/8 [02:30<01:17, 25.89s/it]
# OpenFF Phosphate Torsion Drives v1.0
#  75%|█████████████████████████████████▊           | 6/8 [02:39<00:40, 20.12s/it]
# OpenFF Alkane Torsion Drives v1.0
#  88%|███████████████████████████████████████▍     | 7/8 [02:43<00:14, 14.75s/it]
# OpenFF Cresset Additional Coverage TorsionDrives v4.0
# 100%|█████████████████████████████████████████████| 8/8 [02:46<00:00, 20.76s/it]

# %%
from yammbs.checkmol import analyse_functional_groups, ChemicalEnvironment

# %%
datasets = client.list_datasets()
datasets
# Out:
# [{'id': 35,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'OpenFF Fragmenter Phenyl Benchmark',
#   'record_count': 454},
#  {'id': 36,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'OpenFF Group1 Torsions',
#   'record_count': 820},
#  {'id': 41,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Optimization Set 1',
#   'record_count': 937},
#  {'id': 42,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'Fragment Stability Benchmark',
#   'record_count': 86},
#  {'id': 43,
#   'dataset_type': 'optimization',
#   'dataset_name': 'SMIRNOFF Coverage Set 1',
#   'record_count': 1132},
#  {'id': 45,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF VEHICLe Set 1',
#   'record_count': 25500},
#  {'id': 48,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'SMIRNOFF Coverage Torsion Set 1',
#   'record_count': 585},
#  {'id': 49,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF NCI250K Boron 1',
#   'record_count': 189},
#  {'id': 50,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Discrepancy Benchmark 1',
#   'record_count': 19714},
#  {'id': 57,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'OpenFF Substituted Phenyl Set 1',
#   'record_count': 795},
#  {'id': 68,
#   'dataset_type': 'optimization',
#   'dataset_name': 'Pfizer Discrepancy Optimization Dataset 1',
#   'record_count': 352},
#  {'id': 69,
#   'dataset_type': 'optimization',
#   'dataset_name': 'FDA Optimization Dataset 1',
#   'record_count': 6670},
#  {'id': 70,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'Pfizer Discrepancy Torsion Dataset 1',
#   'record_count': 227},
#  {'id': 71,
#   'dataset_type': 'gridoptimization',
#   'dataset_name': 'OpenFF Trivalent Nitrogen Set 1 (deprecated)',
#   'record_count': 311},
#  {'id': 148,
#   'dataset_type': 'reaction',
#   'dataset_name': 'AlkIsod14',
#   'record_count': 994},
#  {'id': 149,
#   'dataset_type': 'reaction',
#   'dataset_name': 'BHPERI26',
#   'record_count': 1846},
#  {'id': 151,
#   'dataset_type': 'singlepoint',
#   'dataset_name': 'OpenFF Optimization Set 1',
#   'record_count': 937},
#  {'id': 152,
#   'dataset_type': 'singlepoint',
#   'dataset_name': 'OpenFF VEHICLe Set 1',
#   'record_count': 48280},
#  {'id': 153,
#   'dataset_type': 'singlepoint',
#   'dataset_name': 'OpenFF NCI250K Boron 1',
#   'record_count': 189},
#  {'id': 156,
#   'dataset_type': 'reaction',
#   'dataset_name': 'CYCONF',
#   'record_count': 710},
#  {'id': 159,
#   'dataset_type': 'singlepoint',
#   'dataset_name': 'OpenFF Discrepancy Benchmark 1',
#   'record_count': 18864},
#  {'id': 161,
#   'dataset_type': 'reaction',
#   'dataset_name': 'Butanediol65',
#   'record_count': 4544},
#  {'id': 163,
#   'dataset_type': 'reaction',
#   'dataset_name': 'ACONF',
#   'record_count': 1065},
#  {'id': 164,
#   'dataset_type': 'reaction',
#   'dataset_name': 'HNBrBDE18',
#   'record_count': 1278},
#  {'id': 165,
#   'dataset_type': 'reaction',
#   'dataset_name': 'MPCONF196',
#   'record_count': 12936},
#  {'id': 167,
#   'dataset_type': 'reaction',
#   'dataset_name': 'AlkIsomer11',
#   'record_count': 781},
#  {'id': 170,
#   'dataset_type': 'reaction',
#   'dataset_name': 'BSR36',
#   'record_count': 2556},
#  {'id': 171,
#   'dataset_type': 'reaction',
#   'dataset_name': 'BH76RC',
#   'record_count': 2130},
#  {'id': 173,
#   'dataset_type': 'reaction',
#   'dataset_name': 'C20C24',
#   'record_count': 426},
#  {'id': 174,
#   'dataset_type': 'singlepoint',
#   'dataset_name': 'SMIRNOFF Coverage Set 1',
#   'record_count': 1109},
#  {'id': 194,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'OpenFF Primary TorsionDrive Benchmark 1',
#   'record_count': 31},
#  {'id': 195,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'OpenFF Full TorsionDrive Benchmark 1',
#   'record_count': 227},
#  {'id': 196,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Primary Optimization Benchmark 1',
#   'record_count': 1885},
#  {'id': 197,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Full Optimization Benchmark 1',
#   'record_count': 26736},
#  {'id': 213,
#   'dataset_type': 'singlepoint',
#   'dataset_name': 'Solvated Protein Fragments',
#   'record_count': 0},
#  {'id': 217,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'TorsionDrive Paper',
#   'record_count': 4},
#  {'id': 231,
#   'dataset_type': 'gridoptimization',
#   'dataset_name': 'OpenFF Trivalent Nitrogen Set 1',
#   'record_count': 311},
#  {'id': 232,
#   'dataset_type': 'optimization',
#   'dataset_name': 'Kinase Inhibitors: WBO Distributions',
#   'record_count': 6567},
#  {'id': 235,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'OpenFF Primary Benchmark 1 Torsion Set',
#   'record_count': 259},
#  {'id': 237,
#   'dataset_type': 'gridoptimization',
#   'dataset_name': 'OpenFF Trivalent Nitrogen Set 2',
#   'record_count': 311},
#  {'id': 239,
#   'dataset_type': 'gridoptimization',
#   'dataset_name': 'OpenFF Trivalent Nitrogen Set 3',
#   'record_count': 126},
#  {'id': 241,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'OpenFF Primary Benchmark 2 Torsion Set',
#   'record_count': 595},
#  {'id': 242,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'OpenFF Group1 Torsions 2',
#   'record_count': 19},
#  {'id': 243,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'OpenFF Group1 Torsions 3',
#   'record_count': 6},
#  {'id': 245,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'OpenFF Gen 2 Torsion Set 1 Roche',
#   'record_count': 65},
#  {'id': 246,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'OpenFF Gen 2 Torsion Set 2 Coverage',
#   'record_count': 93},
#  {'id': 247,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'OpenFF Gen 2 Torsion Set 3 Pfizer Discrepancy',
#   'record_count': 38},
#  {'id': 248,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'OpenFF Gen 2 Torsion Set 4 eMolecules Discrepancy',
#   'record_count': 106},
#  {'id': 249,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'OpenFF Gen 2 Torsion Set 5 Bayer',
#   'record_count': 100},
#  {'id': 250,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'OpenFF Gen 2 Torsion Set 6 Supplemental',
#   'record_count': 7},
#  {'id': 251,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Gen 2 Opt Set 1 Roche',
#   'record_count': 298},
#  {'id': 253,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Gen 2 Opt Set 2 Coverage',
#   'record_count': 373},
#  {'id': 254,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Gen 2 Opt Set 4 eMolecules Discrepancy',
#   'record_count': 2201},
#  {'id': 255,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Gen 2 Opt Set 3 Pfizer Discrepancy',
#   'record_count': 197},
#  {'id': 256,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'OpenFF Gen 2 Torsion Set 1 Roche 2',
#   'record_count': 142},
#  {'id': 257,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'OpenFF Gen 2 Torsion Set 2 Coverage 2',
#   'record_count': 157},
#  {'id': 258,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'OpenFF Gen 2 Torsion Set 3 Pfizer Discrepancy 2',
#   'record_count': 82},
#  {'id': 259,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'OpenFF Gen 2 Torsion Set 4 eMolecules Discrepancy 2',
#   'record_count': 272},
#  {'id': 260,
#   'dataset_type': 'singlepoint',
#   'dataset_name': 'OpenFF Gen 2 Opt Set 1 Roche',
#   'record_count': 298},
#  {'id': 262,
#   'dataset_type': 'singlepoint',
#   'dataset_name': 'OpenFF Gen 2 Opt Set 2 Coverage',
#   'record_count': 352},
#  {'id': 263,
#   'dataset_type': 'singlepoint',
#   'dataset_name': 'OpenFF Gen 2 Opt Set 3 Pfizer Discrepancy',
#   'record_count': 197},
#  {'id': 264,
#   'dataset_type': 'singlepoint',
#   'dataset_name': 'OpenFF Gen 2 Opt Set 4 eMolecules Discrepancy',
#   'record_count': 2181},
#  {'id': 265,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'OpenFF Gen 2 Torsion Set 5 Bayer 2',
#   'record_count': 219},
#  {'id': 266,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'OpenFF Gen 2 Torsion Set 6 Supplemental 2',
#   'record_count': 22},
#  {'id': 268,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'SiliconTX Torsion Benchmark Set 1',
#   'record_count': 1459},
#  {'id': 270,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Gen 2 Opt Set 5 Bayer',
#   'record_count': 1850},
#  {'id': 272,
#   'dataset_type': 'singlepoint',
#   'dataset_name': 'OpenFF Gen 2 Opt Set 5 Bayer',
#   'record_count': 1772},
#  {'id': 275,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'Fragmenter paper',
#   'record_count': 462},
#  {'id': 278,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'OpenFF Fragmenter Validation 1.0',
#   'record_count': 440},
#  {'id': 279,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Ehrman Informative Optimization v0.1',
#   'record_count': 3485},
#  {'id': 281,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Ehrman Informative Optimization v0.2',
#   'record_count': 3485},
#  {'id': 282,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'OpenFF DANCE 1 eMolecules t142 v1.0',
#   'record_count': 20},
#  {'id': 283,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'OpenFF Rowley Biaryl v1.0',
#   'record_count': 87},
#  {'id': 284,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Protein Fragments v1.0',
#   'record_count': 576},
#  {'id': 285,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'OpenFF Theory Benchmarking Set B3LYP-D3BJ DZVP v1.0',
#   'record_count': 36},
#  {'id': 286,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'OpenFF Theory Benchmarking Set B3LYP-D3BJ def2-TZVP v1.0',
#   'record_count': 36},
#  {'id': 287,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'OpenFF Theory Benchmarking Set B3LYP-D3BJ def2-TZVPD v1.0',
#   'record_count': 36},
#  {'id': 288,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'OpenFF Theory Benchmarking Set B3LYP-D3BJ def2-TZVPP v1.0',
#   'record_count': 36},
#  {'id': 289,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'OpenFF-benchmark-ligand-fragments-v1.0',
#   'record_count': 3848},
#  {'id': 290,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Protein Fragments v2.0',
#   'record_count': 6716},
#  {'id': 291,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'OpenFF Protein Fragments TorsionDrives v1.0',
#   'record_count': 845},
#  {'id': 296,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Sandbox CHO PhAlkEthOH v1.0',
#   'record_count': 85897},
#  {'id': 297,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Protein Peptide Fragments constrained v1.0',
#   'record_count': 6716},
#  {'id': 298,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Protein Peptide Fragments unconstrained v1.0',
#   'record_count': 6709},
#  {'id': 299,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'OpenFF Theory Benchmarking Set B3LYP-D3BJ 6-31+Gss',
#   'record_count': 36},
#  {'id': 300,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'OpenFF Theory Benchmarking Set B3LYP-D3BJ def2-TZVPPD',
#   'record_count': 36},
#  {'id': 301,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF PEPCONF OptimizationDataset v1.0',
#   'record_count': 22680},
#  {'id': 302,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'OpenFF Substituted Phenyl Set 1 v2.0',
#   'record_count': 780},
#  {'id': 303,
#   'dataset_type': 'singlepoint',
#   'dataset_name': 'OpenFF BCC Refit Study COH v1.0',
#   'record_count': 382},
#  {'id': 304,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Roche Opt Set With Protomers and Tautomers v1.0',
#   'record_count': 1376},
#  {'id': 305,
#   'dataset_type': 'optimization',
#   'dataset_name': 'Genentech PDB Ligand Expo whole optimization neutral v1.0',
#   'record_count': 445},
#  {'id': 307,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Roche Opt Set With Protomers and Tautomers v1.1',
#   'record_count': 1376},
#  {'id': 308,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'OpenFF WBO Conjugated Series v1.0',
#   'record_count': 787},
#  {'id': 309,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'OpenFF Theory Benchmarking Set v1.0',
#   'record_count': 767},
#  {'id': 310,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Theory Benchmarking Constrained Optimization Set B3LYP-NL def2-TZVPD v1.0',
#   'record_count': 864},
#  {'id': 311,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Theory Benchmarking Constrained Optimization Set MP2 heavy-aug-cc-pVTZ v1.0',
#   'record_count': 864},
#  {'id': 312,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Theory Benchmarking Constrained Optimization Set WB97X-V def2-TZVPD v1.0',
#   'record_count': 864},
#  {'id': 313,
#   'dataset_type': 'optimization',
#   'dataset_name': 'Genentech PDB Ligand Expo fragment optimization neutral v1.0',
#   'record_count': 2363},
#  {'id': 314,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'OpenFF Amide Torsion Set v1.0',
#   'record_count': 260},
#  {'id': 315,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Aniline Para Opt v1.0',
#   'record_count': 223},
#  {'id': 316,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Industry Benchmark Season 1 v1.0',
#   'record_count': 69672},
#  {'id': 317,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'OpenFF Gen3 Torsion Set v1.0',
#   'record_count': 888},
#  {'id': 318,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'OpenFF Aniline 2D Impropers v1.0',
#   'record_count': 24},
#  {'id': 319,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Industry Benchmark Season 1 v1.1',
#   'record_count': 539385},
#  {'id': 320,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF BCC Refit Study COH v2.0',
#   'record_count': 4650},
#  {'id': 321,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Theory Benchmarking Constrained Optimization Set MP2 heavy-aug-cc-pVTZ v1.1',
#   'record_count': 1416},
#  {'id': 322,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Industry Benchmark Season 1 - MM v1.1',
#   'record_count': 501585},
#  {'id': 323,
#   'dataset_type': 'singlepoint',
#   'dataset_name': 'OpenFF Theory Benchmarking Single Point Energies v1.0',
#   'record_count': 66552},
#  {'id': 324,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'OpenFF-benchmark-ligand-fragments-v2.0',
#   'record_count': 8052},
#  {'id': 326,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF RESP Polarizability Optimizations v1.0',
#   'record_count': 735},
#  {'id': 327,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF RESP Polarizability Optimizations v1.1',
#   'record_count': 735},
#  {'id': 329,
#   'dataset_type': 'singlepoint',
#   'dataset_name': 'TorsionNet500 Single Points Dataset v1.0',
#   'record_count': 24000},
#  {'id': 333,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'OpenFF Protein Dipeptide 2-D TorsionDrive v1.0',
#   'record_count': 5},
#  {'id': 344,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'OpenFF Protein Dipeptide 2-D TorsionDrive v1.1',
#   'record_count': 5},
#  {'id': 345,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Gen2 Optimization Dataset Protomers v1.0',
#   'record_count': 600},
#  {'id': 346,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'OpenFF Protein Dipeptide 2-D TorsionDrive v2.0',
#   'record_count': 26},
#  {'id': 347,
#   'dataset_type': 'singlepoint',
#   'dataset_name': 'OpenFF ESP Fragment Conformers v1.0',
#   'record_count': 65116},
#  {'id': 351,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF ESP Industry Benchmark Set v1.0',
#   'record_count': 56054},
#  {'id': 352,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'OpenFF Protein Capped 1-mer Sidechains v1.0',
#   'record_count': 46},
#  {'id': 353,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'OpenFF Protein Dipeptide 2-D TorsionDrive v2.1',
#   'record_count': 26},
#  {'id': 357,
#   'dataset_type': 'singlepoint',
#   'dataset_name': 'OpenFF ESP Industry Benchmark Set v1.1',
#   'record_count': 39983},
#  {'id': 358,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'OpenFF Protein Capped 1-mer Sidechains v1.1',
#   'record_count': 46},
#  {'id': 359,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'OpenFF Protein Capped 1-mer Sidechains v1.2',
#   'record_count': 46},
#  {'id': 360,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'OpenFF Protein Capped 1-mer Sidechains v1.3',
#   'record_count': 61},
#  {'id': 363,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF multiplicity correction optimization set v1.0',
#   'record_count': 400},
#  {'id': 364,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'OpenFF multiplicity correction torsion drive data v1.0',
#   'record_count': 99},
#  {'id': 365,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Protein Capped 1-mers 3-mers Optimization Dataset v1.0',
#   'record_count': 759},
#  {'id': 366,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'OpenFF Protein Capped 3-mer Backbones v1.0',
#   'record_count': 54},
#  {'id': 370,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'OpenFF multiplicity correction torsion drive data v1.1',
#   'record_count': 131},
#  {'id': 371,
#   'dataset_type': 'singlepoint',
#   'dataset_name': 'RNA Single Point Dataset v1.0',
#   'record_count': 13467},
#  {'id': 372,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Iodine Chemistry Optimization Dataset v1.0',
#   'record_count': 327},
#  {'id': 373,
#   'dataset_type': 'singlepoint',
#   'dataset_name': 'RNA Trinucleotide Single Point Dataset v1.0',
#   'record_count': 81670},
#  {'id': 374,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'OpenFF Protein Capped 3-mer Omega v1.0',
#   'record_count': 26},
#  {'id': 375,
#   'dataset_type': 'singlepoint',
#   'dataset_name': 'RNA Nucleoside Single Point Dataset v1.0',
#   'record_count': 19110},
#  {'id': 376,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF multi-Br ESP Fragment Conformers v1.0',
#   'record_count': 677},
#  {'id': 377,
#   'dataset_type': 'singlepoint',
#   'dataset_name': 'OpenFF multi-Br ESP Fragment Conformers v1.1',
#   'record_count': 650},
#  {'id': 378,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'XtalPi Shared Fragments TorsiondriveDataset v1.0',
#   'record_count': 169},
#  {'id': 379,
#   'dataset_type': 'optimization',
#   'dataset_name': 'XtalPi Shared Fragments OptimizationDataset v1.0',
#   'record_count': 2384},
#  {'id': 380,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'OpenFF Torsion Coverage Supplement v1.0',
#   'record_count': 43},
#  {'id': 381,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'OpenFF RNA Dinucleoside Monophosphate TorsionDrives v1.0',
#   'record_count': 192},
#  {'id': 382,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'XtalPi 20-percent Fragments TorsiondriveDataset v1.0',
#   'record_count': 8737},
#  {'id': 383,
#   'dataset_type': 'optimization',
#   'dataset_name': 'XtalPi 20-percent Fragments OptimizationDataset v1.0',
#   'record_count': 128180},
#  {'id': 384,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'OpenFF Torsion Drive Supplement v1.0',
#   'record_count': 18},
#  {'id': 385,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Torsion Benchmark Supplement v1.0',
#   'record_count': 51},
#  {'id': 386,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'OpenFF Torsion Multiplicity Torsion Drive Coverage Supplement v1.0',
#   'record_count': 59},
#  {'id': 387,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Torsion Multiplicity Optimization Training Coverage Supplement v1.0',
#   'record_count': 185},
#  {'id': 388,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Torsion Multiplicity Optimization Benchmarking Coverage Supplement v1.0',
#   'record_count': 451},
#  {'id': 389,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'OpenFF Phosphate Torsion Drives v1.0',
#   'record_count': 318},
#  {'id': 390,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'OpenFF Alkane Torsion Drives v1.0',
#   'record_count': 192},
#  {'id': 391,
#   'dataset_type': 'singlepoint',
#   'dataset_name': 'MLPepper RECAP Optimized Fragments v1.0',
#   'record_count': 137932},
#  {'id': 392,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Iodine Fragment Opt v1.0',
#   'record_count': 531},
#  {'id': 393,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Sulfur Optimization Training Coverage Supplement v1.0',
#   'record_count': 899},
#  {'id': 394,
#   'dataset_type': 'singlepoint',
#   'dataset_name': 'OpenFF NAGL2 ESP Timing Benchmark v1.0',
#   'record_count': 1009},
#  {'id': 395,
#   'dataset_type': 'singlepoint',
#   'dataset_name': 'OpenFF NAGL2 ESP Timing Benchmark v1.1',
#   'record_count': 6054},
#  {'id': 396,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Sulfur Optimization Benchmarking Coverage Supplement v1.0',
#   'record_count': 319},
#  {'id': 397,
#   'dataset_type': 'singlepoint',
#   'dataset_name': 'OpenFF Sulfur Hessian Training Coverage Supplement v1.0',
#   'record_count': 899},
#  {'id': 398,
#   'dataset_type': 'singlepoint',
#   'dataset_name': 'OpenFF Aniline Para Hessian v1.0',
#   'record_count': 223},
#  {'id': 399,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Lipid Optimization Training Supplement v1.0',
#   'record_count': 29770},
#  {'id': 400,
#   'dataset_type': 'singlepoint',
#   'dataset_name': 'MLPepper RECAP Optimized Fragments v1.0 Add Iodines',
#   'record_count': 12262},
#  {'id': 401,
#   'dataset_type': 'singlepoint',
#   'dataset_name': 'OpenFF Sulfur Hessian Training Coverage Supplement v1.1',
#   'record_count': 899},
#  {'id': 402,
#   'dataset_type': 'singlepoint',
#   'dataset_name': 'OpenFF Iodine Chemistry Hessian Dataset v1.0',
#   'record_count': 327},
#  {'id': 403,
#   'dataset_type': 'singlepoint',
#   'dataset_name': 'OpenFF Gen2 Hessian Dataset Protomers v1.1',
#   'record_count': 597},
#  {'id': 404,
#   'dataset_type': 'singlepoint',
#   'dataset_name': 'OpenFF Aniline Para Hessian v1.1',
#   'record_count': 223},
#  {'id': 405,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF NAGL2 Training Optimization Dataset Part 1 v4.0',
#   'record_count': 131185},
#  {'id': 406,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF NAGL2 Training Optimization Dataset Part 2 v4.0',
#   'record_count': 2323},
#  {'id': 407,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF NAGL2 Training Optimization Dataset v4.0',
#   'record_count': 128281},
#  {'id': 408,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Organometallics Exploratory Optimization Dataset v1.0',
#   'record_count': 239},
#  {'id': 409,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Sage 2.0.0 Training Optimization Dataset v1.0',
#   'record_count': 3663},
#  {'id': 410,
#   'dataset_type': 'optimization',
#   'dataset_name': 'SPICE Dipeptides Lowest E Conformer Optimization Dataset v4.0',
#   'record_count': 677},
#  {'id': 411,
#   'dataset_type': 'optimization',
#   'dataset_name': 'SPICE DES370k Monomers Lowest E Conformer Optimization Dataset v4.0',
#   'record_count': 374},
#  {'id': 412,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Lipid Optimization Benchmark Supplement v1.0',
#   'record_count': 8387},
#  {'id': 413,
#   'dataset_type': 'torsiondrive',
#   'dataset_name': 'OpenFF Cresset Additional Coverage TorsionDrives v4.0',
#   'record_count': 82},
#  {'id': 414,
#   'dataset_type': 'optimization',
#   'dataset_name': 'SPICE Dipeptides Partial Relaxation Dataset v4.0',
#   'record_count': 33850},
#  {'id': 415,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Cresset Additional Coverage Optimizations v4.0',
#   'record_count': 393},
#  {'id': 416,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Protein PDB 4-mers v4.0',
#   'record_count': 1000},
#  {'id': 417,
#   'dataset_type': 'optimization',
#   'dataset_name': 'SPICE DES370k Monomers Partial Relaxation Dataset v4.0',
#   'record_count': 18700},
#  {'id': 419,
#   'dataset_type': 'singlepoint',
#   'dataset_name': 'Curated tmQM-xtb Dataset: T=100K Dataset Restricted to Pd, Zn, Fe, Cu v0.0',
#   'record_count': 675204},
#  {'id': 420,
#   'dataset_type': 'optimization',
#   'dataset_name': 'PDB CCD Chemical Space A: Optimization Dataset v0.0',
#   'record_count': 411}]

# %%
opts = [ds for ds in datasets if ds["dataset_type"] == "optimization"]

# %%
opts
# Out:
# [{'id': 41,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Optimization Set 1',
#   'record_count': 937},
#  {'id': 43,
#   'dataset_type': 'optimization',
#   'dataset_name': 'SMIRNOFF Coverage Set 1',
#   'record_count': 1132},
#  {'id': 45,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF VEHICLe Set 1',
#   'record_count': 25500},
#  {'id': 49,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF NCI250K Boron 1',
#   'record_count': 189},
#  {'id': 50,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Discrepancy Benchmark 1',
#   'record_count': 19714},
#  {'id': 68,
#   'dataset_type': 'optimization',
#   'dataset_name': 'Pfizer Discrepancy Optimization Dataset 1',
#   'record_count': 352},
#  {'id': 69,
#   'dataset_type': 'optimization',
#   'dataset_name': 'FDA Optimization Dataset 1',
#   'record_count': 6670},
#  {'id': 196,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Primary Optimization Benchmark 1',
#   'record_count': 1885},
#  {'id': 197,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Full Optimization Benchmark 1',
#   'record_count': 26736},
#  {'id': 232,
#   'dataset_type': 'optimization',
#   'dataset_name': 'Kinase Inhibitors: WBO Distributions',
#   'record_count': 6567},
#  {'id': 251,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Gen 2 Opt Set 1 Roche',
#   'record_count': 298},
#  {'id': 253,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Gen 2 Opt Set 2 Coverage',
#   'record_count': 373},
#  {'id': 254,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Gen 2 Opt Set 4 eMolecules Discrepancy',
#   'record_count': 2201},
#  {'id': 255,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Gen 2 Opt Set 3 Pfizer Discrepancy',
#   'record_count': 197},
#  {'id': 270,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Gen 2 Opt Set 5 Bayer',
#   'record_count': 1850},
#  {'id': 279,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Ehrman Informative Optimization v0.1',
#   'record_count': 3485},
#  {'id': 281,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Ehrman Informative Optimization v0.2',
#   'record_count': 3485},
#  {'id': 284,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Protein Fragments v1.0',
#   'record_count': 576},
#  {'id': 290,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Protein Fragments v2.0',
#   'record_count': 6716},
#  {'id': 296,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Sandbox CHO PhAlkEthOH v1.0',
#   'record_count': 85897},
#  {'id': 297,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Protein Peptide Fragments constrained v1.0',
#   'record_count': 6716},
#  {'id': 298,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Protein Peptide Fragments unconstrained v1.0',
#   'record_count': 6709},
#  {'id': 301,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF PEPCONF OptimizationDataset v1.0',
#   'record_count': 22680},
#  {'id': 304,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Roche Opt Set With Protomers and Tautomers v1.0',
#   'record_count': 1376},
#  {'id': 305,
#   'dataset_type': 'optimization',
#   'dataset_name': 'Genentech PDB Ligand Expo whole optimization neutral v1.0',
#   'record_count': 445},
#  {'id': 307,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Roche Opt Set With Protomers and Tautomers v1.1',
#   'record_count': 1376},
#  {'id': 310,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Theory Benchmarking Constrained Optimization Set B3LYP-NL def2-TZVPD v1.0',
#   'record_count': 864},
#  {'id': 311,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Theory Benchmarking Constrained Optimization Set MP2 heavy-aug-cc-pVTZ v1.0',
#   'record_count': 864},
#  {'id': 312,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Theory Benchmarking Constrained Optimization Set WB97X-V def2-TZVPD v1.0',
#   'record_count': 864},
#  {'id': 313,
#   'dataset_type': 'optimization',
#   'dataset_name': 'Genentech PDB Ligand Expo fragment optimization neutral v1.0',
#   'record_count': 2363},
#  {'id': 315,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Aniline Para Opt v1.0',
#   'record_count': 223},
#  {'id': 316,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Industry Benchmark Season 1 v1.0',
#   'record_count': 69672},
#  {'id': 319,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Industry Benchmark Season 1 v1.1',
#   'record_count': 539385},
#  {'id': 320,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF BCC Refit Study COH v2.0',
#   'record_count': 4650},
#  {'id': 321,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Theory Benchmarking Constrained Optimization Set MP2 heavy-aug-cc-pVTZ v1.1',
#   'record_count': 1416},
#  {'id': 322,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Industry Benchmark Season 1 - MM v1.1',
#   'record_count': 501585},
#  {'id': 326,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF RESP Polarizability Optimizations v1.0',
#   'record_count': 735},
#  {'id': 327,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF RESP Polarizability Optimizations v1.1',
#   'record_count': 735},
#  {'id': 345,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Gen2 Optimization Dataset Protomers v1.0',
#   'record_count': 600},
#  {'id': 351,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF ESP Industry Benchmark Set v1.0',
#   'record_count': 56054},
#  {'id': 363,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF multiplicity correction optimization set v1.0',
#   'record_count': 400},
#  {'id': 365,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Protein Capped 1-mers 3-mers Optimization Dataset v1.0',
#   'record_count': 759},
#  {'id': 372,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Iodine Chemistry Optimization Dataset v1.0',
#   'record_count': 327},
#  {'id': 376,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF multi-Br ESP Fragment Conformers v1.0',
#   'record_count': 677},
#  {'id': 379,
#   'dataset_type': 'optimization',
#   'dataset_name': 'XtalPi Shared Fragments OptimizationDataset v1.0',
#   'record_count': 2384},
#  {'id': 383,
#   'dataset_type': 'optimization',
#   'dataset_name': 'XtalPi 20-percent Fragments OptimizationDataset v1.0',
#   'record_count': 128180},
#  {'id': 385,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Torsion Benchmark Supplement v1.0',
#   'record_count': 51},
#  {'id': 387,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Torsion Multiplicity Optimization Training Coverage Supplement v1.0',
#   'record_count': 185},
#  {'id': 388,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Torsion Multiplicity Optimization Benchmarking Coverage Supplement v1.0',
#   'record_count': 451},
#  {'id': 392,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Iodine Fragment Opt v1.0',
#   'record_count': 531},
#  {'id': 393,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Sulfur Optimization Training Coverage Supplement v1.0',
#   'record_count': 899},
#  {'id': 396,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Sulfur Optimization Benchmarking Coverage Supplement v1.0',
#   'record_count': 319},
#  {'id': 399,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Lipid Optimization Training Supplement v1.0',
#   'record_count': 29770},
#  {'id': 405,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF NAGL2 Training Optimization Dataset Part 1 v4.0',
#   'record_count': 131185},
#  {'id': 406,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF NAGL2 Training Optimization Dataset Part 2 v4.0',
#   'record_count': 2323},
#  {'id': 407,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF NAGL2 Training Optimization Dataset v4.0',
#   'record_count': 128281},
#  {'id': 408,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Organometallics Exploratory Optimization Dataset v1.0',
#   'record_count': 239},
#  {'id': 409,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Sage 2.0.0 Training Optimization Dataset v1.0',
#   'record_count': 3663},
#  {'id': 410,
#   'dataset_type': 'optimization',
#   'dataset_name': 'SPICE Dipeptides Lowest E Conformer Optimization Dataset v4.0',
#   'record_count': 677},
#  {'id': 411,
#   'dataset_type': 'optimization',
#   'dataset_name': 'SPICE DES370k Monomers Lowest E Conformer Optimization Dataset v4.0',
#   'record_count': 374},
#  {'id': 412,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Lipid Optimization Benchmark Supplement v1.0',
#   'record_count': 8387},
#  {'id': 414,
#   'dataset_type': 'optimization',
#   'dataset_name': 'SPICE Dipeptides Partial Relaxation Dataset v4.0',
#   'record_count': 33850},
#  {'id': 415,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Cresset Additional Coverage Optimizations v4.0',
#   'record_count': 393},
#  {'id': 416,
#   'dataset_type': 'optimization',
#   'dataset_name': 'OpenFF Protein PDB 4-mers v4.0',
#   'record_count': 1000},
#  {'id': 417,
#   'dataset_type': 'optimization',
#   'dataset_name': 'SPICE DES370k Monomers Partial Relaxation Dataset v4.0',
#   'record_count': 18700},
#  {'id': 420,
#   'dataset_type': 'optimization',
#   'dataset_name': 'PDB CCD Chemical Space A: Optimization Dataset v0.0',
#   'record_count': 411}]

# %%
dataset_names = [opt["dataset_name"] for opt in opts]
dataset_names
# Out:
# ['OpenFF Optimization Set 1',
#  'SMIRNOFF Coverage Set 1',
#  'OpenFF VEHICLe Set 1',
#  'OpenFF NCI250K Boron 1',
#  'OpenFF Discrepancy Benchmark 1',
#  'Pfizer Discrepancy Optimization Dataset 1',
#  'FDA Optimization Dataset 1',
#  'OpenFF Primary Optimization Benchmark 1',
#  'OpenFF Full Optimization Benchmark 1',
#  'Kinase Inhibitors: WBO Distributions',
#  'OpenFF Gen 2 Opt Set 1 Roche',
#  'OpenFF Gen 2 Opt Set 2 Coverage',
#  'OpenFF Gen 2 Opt Set 4 eMolecules Discrepancy',
#  'OpenFF Gen 2 Opt Set 3 Pfizer Discrepancy',
#  'OpenFF Gen 2 Opt Set 5 Bayer',
#  'OpenFF Ehrman Informative Optimization v0.1',
#  'OpenFF Ehrman Informative Optimization v0.2',
#  'OpenFF Protein Fragments v1.0',
#  'OpenFF Protein Fragments v2.0',
#  'OpenFF Sandbox CHO PhAlkEthOH v1.0',
#  'OpenFF Protein Peptide Fragments constrained v1.0',
#  'OpenFF Protein Peptide Fragments unconstrained v1.0',
#  'OpenFF PEPCONF OptimizationDataset v1.0',
#  'OpenFF Roche Opt Set With Protomers and Tautomers v1.0',
#  'Genentech PDB Ligand Expo whole optimization neutral v1.0',
#  'OpenFF Roche Opt Set With Protomers and Tautomers v1.1',
#  'OpenFF Theory Benchmarking Constrained Optimization Set B3LYP-NL def2-TZVPD v1.0',
#  'OpenFF Theory Benchmarking Constrained Optimization Set MP2 heavy-aug-cc-pVTZ v1.0',
#  'OpenFF Theory Benchmarking Constrained Optimization Set WB97X-V def2-TZVPD v1.0',
#  'Genentech PDB Ligand Expo fragment optimization neutral v1.0',
#  'OpenFF Aniline Para Opt v1.0',
#  'OpenFF Industry Benchmark Season 1 v1.0',
#  'OpenFF Industry Benchmark Season 1 v1.1',
#  'OpenFF BCC Refit Study COH v2.0',
#  'OpenFF Theory Benchmarking Constrained Optimization Set MP2 heavy-aug-cc-pVTZ v1.1',
#  'OpenFF Industry Benchmark Season 1 - MM v1.1',
#  'OpenFF RESP Polarizability Optimizations v1.0',
#  'OpenFF RESP Polarizability Optimizations v1.1',
#  'OpenFF Gen2 Optimization Dataset Protomers v1.0',
#  'OpenFF ESP Industry Benchmark Set v1.0',
#  'OpenFF multiplicity correction optimization set v1.0',
#  'OpenFF Protein Capped 1-mers 3-mers Optimization Dataset v1.0',
#  'OpenFF Iodine Chemistry Optimization Dataset v1.0',
#  'OpenFF multi-Br ESP Fragment Conformers v1.0',
#  'XtalPi Shared Fragments OptimizationDataset v1.0',
#  'XtalPi 20-percent Fragments OptimizationDataset v1.0',
#  'OpenFF Torsion Benchmark Supplement v1.0',
#  'OpenFF Torsion Multiplicity Optimization Training Coverage Supplement v1.0',
#  'OpenFF Torsion Multiplicity Optimization Benchmarking Coverage Supplement v1.0',
#  'OpenFF Iodine Fragment Opt v1.0',
#  'OpenFF Sulfur Optimization Training Coverage Supplement v1.0',
#  'OpenFF Sulfur Optimization Benchmarking Coverage Supplement v1.0',
#  'OpenFF Lipid Optimization Training Supplement v1.0',
#  'OpenFF NAGL2 Training Optimization Dataset Part 1 v4.0',
#  'OpenFF NAGL2 Training Optimization Dataset Part 2 v4.0',
#  'OpenFF NAGL2 Training Optimization Dataset v4.0',
#  'OpenFF Organometallics Exploratory Optimization Dataset v1.0',
#  'OpenFF Sage 2.0.0 Training Optimization Dataset v1.0',
#  'SPICE Dipeptides Lowest E Conformer Optimization Dataset v4.0',
#  'SPICE DES370k Monomers Lowest E Conformer Optimization Dataset v4.0',
#  'OpenFF Lipid Optimization Benchmark Supplement v1.0',
#  'SPICE Dipeptides Partial Relaxation Dataset v4.0',
#  'OpenFF Cresset Additional Coverage Optimizations v4.0',
#  'OpenFF Protein PDB 4-mers v4.0',
#  'SPICE DES370k Monomers Partial Relaxation Dataset v4.0',
#  'PDB CCD Chemical Space A: Optimization Dataset v0.0']
